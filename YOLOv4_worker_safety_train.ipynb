# %% [markdown]
# <a href="https://colab.research.google.com/github/CosmaBelli/DataScientistTest/blob/master/YOLOv4_worker_safety_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/darknet-master/"
# Out:
# /content/drive/My Drive/darknet-master

# %%
mv Makefile Makefile_orig

# %%
# !make
# !chmod +x ./darknet
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 2s (222 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %%
cd data
# Out:
# /content/drive/My Drive/darknet-master/data

# %%
cd data/Worker_Safety/train/images/
# Out:
# /content/drive/My Drive/darknet-master/data/Worker_Safety/train/images

# %%
ls
# Out:
# filenames_path.py       hard_hat_workers4.png  maksssksksss16.png
# hard_hat_workers0.png   hard_hat_workers5.png  maksssksksss1.png
# hard_hat_workers10.png  hard_hat_workers6.png  maksssksksss2.png
# hard_hat_workers11.png  hard_hat_workers7.png  maksssksksss3.png
# hard_hat_workers13.png  hard_hat_workers9.png  maksssksksss4.png
# hard_hat_workers14.png  maksssksksss0.png      maksssksksss5.png
# hard_hat_workers15.png  maksssksksss10.png     maksssksksss6.png
# hard_hat_workers16.png  maksssksksss11.png     maksssksksss7.png
# hard_hat_workers1.png   maksssksksss12.png     maksssksksss8.png
# hard_hat_workers2.png   maksssksksss13.png     maksssksksss9.png
# hard_hat_workers3.png   maksssksksss15.png     train.txt

# %%
# !dos2unix train.txt
# Out:
# dos2unix: converting file train.txt to Unix format...

# %%
ls
# Out:
# 3rdparty/               darknet.py              net_cam_v3.sh*
# backup/                 darknet_video.py        net_cam_v4.sh*
# build/                  data/                   obj/
# build.ps1               image_yolov3.sh*        README.md
# build.sh*               image_yolov4.sh*        results/
# cfg/                    include/                scripts/
# cmake/                  json_mjpeg_streams.sh*  src/
# CMakeLists.txt          LICENSE                 video_yolov3.sh*
# darknet*                logs/                   video_yolov4.sh*
# DarknetConfig.cmake.in  Makefile                yolov4.conv.137
# darknet_images.py       Makefile_orig

# %%
cp data/Worker_Safety/train/labels/*.txt data/Worker_Safety/train/images/

# %%
ls
# Out:
# 3rdparty/               darknet_images.py       Makefile_orig
# backup/                 darknet.py              net_cam_v3.sh*
# bad.list                darknet_video.py        net_cam_v4.sh*
# build/                  data/                   obj/
# build.ps1               image_yolov3.sh*        README.md
# build.sh*               image_yolov4.sh*        results/
# cfg/                    include/                scripts/
# cmake/                  json_mjpeg_streams.sh*  src/
# CMakeLists.txt          LICENSE                 video_yolov3.sh*
# darknet*                logs/                   video_yolov4.sh*
# DarknetConfig.cmake.in  Makefile                yolov4.conv.137

# %%
! ./darknet detector train data/workersafety.data cfg/yolov4-workersafety.cfg yolov4.conv.137 -dont_show -> logs/logs.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000010, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.010194, iou_loss = 0.000000, total_loss = 0.010194
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.965032, GIOU: 0.965032), Class: 0.999909, Obj: 0.998811, No Obj: 0.002068, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.000004, iou_loss = 5.050865, total_loss = 5.050869
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.969509, GIOU: 0.969469), Class: 0.999014, Obj: 0.999587, No Obj: 0.001852, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.000010, iou_loss = 1.134286, total_loss = 1.134295
#  total_bbox = 3829059, rewritten_bbox = 0.001515 %
# ...
